# %%
import pandas as pd
import numpy as np

# %%
latents_data = pd.read_json('latents_results.json')
latents_data.head(10)
# Out:
#                               names  \
# 0  1f5e1b0661b340fc81dcc09cafd93d2e
# 1   68b62b9b9d49f262b12ea83455b0f44
# 2  575266906372ef117cc922af3684d251
# 3  f3760c5e8b97149163b803b494079757
# 4  6c449b92891754c6b8b6b17d4ce17d67
# 5  bb7ca919b59a3a2e6b418c7d9fedcaa9
# 6  609f09c6ce74d6c44c06afea25f8c085
# 7  ef3ed9f139571826ce27281f3b76d1f5
# 8  382496958e58e9a0658e57fd275f6bed
# 9  a750b467d629df3e2268f50ab9844c64
#
#                                             raw_data  \
# 0  [[1.024717450141906, -0.717034637928009, 1.579...
# 1  [[0.7599654793739311, 0.043263264000415004, -1...
# 2  [[-0.9319659471511841, -0.42853677272796603, 0...
# 3  [[-0.8434703946113581, -0.5776208639144891, -1...
# 4  [[-0.481881886720657, -0.43148025870323103, 1....
# 5  [[0.035457987338304006, -0.7526748180389401, 1...
# 6  [[-0.487265288829803, 0.130332946777343, -2.53...
# 7  [[-0.23396576941013303, -0.172266885638237, 2....
# 8  [[0.8128136396408081, -0.390083700418472, 2.31...
# ...

# %%
raw_data_0 = np.array(latents_data['raw_data'][0])
raw_data_0.shape
# Out:
# (2048, 3)
